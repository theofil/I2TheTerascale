# %% [markdown]
# <a href="https://colab.research.google.com/github/theofil/I2TheTerascale/blob/main/code/python/openROOTFile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# set this to True if you use Google Colab
runOnGoogle = True
if runOnGoogle: 
    from google.colab import files    
    
    # install uproot, mplhep, awkward at Google Colab
    # !pip install uproot
    # !pip install mplhep
    # !pip install awkward
    print('\n\n\n')
    print('We must restart the runtime in order to use newly installed versions.')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting uproot
#   Downloading uproot-5.0.3-py3-none-any.whl (328 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.4/328.4 KB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from uproot) (23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from uproot) (1.22.4)
# Collecting awkward>=2.0.0
#   Downloading awkward-2.0.8-py3-none-any.whl (583 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 583.2/583.2 KB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from awkward>=2.0.0->uproot) (4.5.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from awkward>=2.0.0->uproot) (5.12.0)
# Collecting awkward-cpp==9
#   Downloading awkward_cpp-9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources->awkward>=2.0.0->uproot) (3.14.0)
# Installing collected packages: awkward-cpp, awkward, uproot
# Successfully installed awkward-2.0.8 awkward-cpp-9 uproot-5.0.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mplhep
#   Downloading mplhep-0.3.26-py3-none-any.whl (34 kB)
# Collecting uhi>=0.2.0
#   Downloading uhi-0.3.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.8/dist-packages (from mplhep) (3.5.3)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from mplhep) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from mplhep) (23.0)
# Collecting mplhep-data
#   Downloading mplhep_data-0.0.3-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 23.5 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->mplhep) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->mplhep) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->mplhep) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->mplhep) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->mplhep) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->mplhep) (7.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4->mplhep) (1.15.0)
# Installing collected packages: uhi, mplhep-data, mplhep
# Successfully installed mplhep-0.3.26 mplhep-data-0.0.3 uhi-0.3.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: awkward in /usr/local/lib/python3.8/dist-packages (2.0.8)
# Requirement already satisfied: awkward-cpp==9 in /usr/local/lib/python3.8/dist-packages (from awkward) (9)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from awkward) (23.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from awkward) (4.5.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from awkward) (5.12.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.8/dist-packages (from awkward) (1.22.4)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources->awkward) (3.14.0)
#
#
#
#
# We must restart the runtime in order to use newly installed versions.

# %%
from google.colab import files # comment this line if you are running this in your computer
import uproot # reading ROOT filies
import mplhep as hep # matplotlib for hep
import matplotlib.pyplot as plt
import numpy as np
import awkward as ak 
import pandas as pd

# %%
# read the TTree named 'events' from the 'data.root'  
events = uproot.open('http://theofil.web.cern.ch/theofil/cmsod/files/data.root:events')

# %%
# check what's inside the 'events'
events.keys()
# Out:
# ['NJet',
#  'Jet_Px',
#  'Jet_Py',
#  'Jet_Pz',
#  'Jet_E',
#  'Jet_btag',
#  'Jet_ID',
#  'NMuon',
#  'Muon_Px',
#  'Muon_Py',
#  'Muon_Pz',
#  'Muon_E',
#  'Muon_Charge',
#  'Muon_Iso',
#  'NElectron',
#  'Electron_Px',
#  'Electron_Py',
#  'Electron_Pz',
#  'Electron_E',
#  'Electron_Charge',
#  'Electron_Iso',
#  'NPhoton',
#  'Photon_Px',
#  'Photon_Py',
#  'Photon_Pz',
#  'Photon_E',
#  'Photon_Iso',
#  'MET_px',
#  'MET_py',
#  'MChadronicBottom_px',
#  'MChadronicBottom_py',
#  'MChadronicBottom_pz',
#  'MCleptonicBottom_px',
#  'MCleptonicBottom_py',
#  'MCleptonicBottom_pz',
#  'MChadronicWDecayQuark_px',
#  'MChadronicWDecayQuark_py',
#  'MChadronicWDecayQuark_pz',
#  'MChadronicWDecayQuarkBar_px',
#  'MChadronicWDecayQuarkBar_py',
#  'MChadronicWDecayQuarkBar_pz',
#  'MClepton_px',
#  'MClepton_py',
#  'MClepton_pz',
#  'MCleptonPDGid',
#  'MCneutrino_px',
#  'MCneutrino_py',
#  'MCneutrino_pz',
#  'NPrimaryVertices',
#  'triggerIsoMu24',
#  'EventWeight']

# %%
# cast NJet and NMuon TBranches into a pandas dataframe, see https://pandas.pydata.org/docs/user_guide/index.html#user-guide
df = events.arrays(['NJet','NMuon'], library = 'pd')

# %%
# print the first 25 raws of the dataframe
df.head(25)
# Out:
#     NJet  NMuon
# 0      0      1
# 1      0      1
# 2      0      0
# 3      1      0
# 4      0      1
# 5      0      1
# 6      0      1
# 7      0      1
# 8      0      0
# 9      0      0
# 10     0      1
# 11     0      0
# 12     3      0
# 13     0      0
# 14     0      1
# 15     2      1
# 16     0      1
# 17     0      1
# 18     1      0
# 19     0      1
# 20     1      1
# 21     0      0
# 22     0      0
# 23     0      1
# 24     3      0

# %%
# save pandas dataframe to txt
df.to_csv('simple.txt',  index=None, sep=',')

# %%
# download simple.txt from Google Colab
files.download('simple.txt')

# %%
# count how many events have NMuon == 1 and NJet >= 2
selection = (df.NMuon ==1) & (df.NJet >= 2)
print(df[selection].shape)
df[selection]
# Out:
# (8055, 2)
#         NJet  NMuon
# 15         2      1
# 43         3      1
# 106        2      1
# 170        2      1
# 195        2      1
# ...      ...    ...
# 469221     2      1
# 469248     2      1
# 469303     2      1
# 469322     2      1
# 469323     2      1
#
# [8055 rows x 2 columns]
